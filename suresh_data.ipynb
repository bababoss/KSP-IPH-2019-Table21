# %%
import sys
print(sys.path.append("/home/ubuntu/anaconda3/envs/almondaiEnv/lib/python3.6/site-packages/arcgis"))
sys.path.append("/home/ubuntu/anaconda3/envs/almondaiEnv/lib/python3.6/site-packages/arcgis-1.7.0-py3.6.egg-info")
import arcpy
billboards_url = 'https://maps.udot.utah.gov/arcgis/rest/services/FI_Mandli2012/MapServer/2'# Calc proximity to billboard
_ = arcpy.analysis.Near('centerlines_merged',
                        billboards_url)
_ = arcpy.management.CalculateField('centerlines_merged','proximity_to_billboard','!NEAR_DIST!')
_ = arcpy.management.DeleteField('centerlines_merged',['NEAR_DIST','NEAR_FID'])
# Out:
# None
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-0f8f0732e520> in <module>()
#       2 print(sys.path.append("/home/ubuntu/anaconda3/envs/almondaiEnv/lib/python3.6/site-packages/arcgis"))
#       3 sys.path.append("/home/ubuntu/anaconda3/envs/almondaiEnv/lib/python3.6/site-packages/arcgis-1.7.0-py3.6.egg-info")
# ----> 4 import arcpy
#       5 billboards_url = 'https://maps.udot.utah.gov/arcgis/rest/services/FI_Mandli2012/MapServer/2'# Calc proximity to billboard
#       6 _ = arcpy.analysis.Near('centerlines_merged',
#
# ModuleNotFoundError: No module named 'arcpy'

# %%
# !ls "/home/ubuntu/anaconda3/envs/almondaiEnv/lib/python3.6/site-packages/"
# Out:
# IPython
# Jinja2-2.10.3.dist-info
# MarkupSafe-1.1.1.dist-info
# Pygments-2.4.2.dist-info
# README.txt
# SecretStorage-3.1.0.dist-info
# Send2Trash-1.5.0-py3.6.egg-info
# __pycache__
# _cffi_backend.cpython-36m-x86_64-linux-gnu.so
# _pyrsistent_version.py
# arcgis
# arcgis-1.7.0-py3.6.egg-info
# asn1crypto
# asn1crypto-1.2.0.dist-info
# attr
# attrs-19.3.0.dist-info
# backcall
# backcall-0.1.0-py3.6.egg-info
# bleach
# bleach-3.1.0-py3.6.egg-info
# certifi
# certifi-2019.9.11-py3.6.egg-info
# cffi
# cffi-1.13.2.dist-info
# cryptography
# cryptography-2.8.dist-info
# cycler-0.10.0-py3.6.egg-info
# cycler.py
# dateutil
# decorator-4.4.1.dist-info
# decorator.py
# defusedxml
# defusedxml-0.6.0-py2.7.egg-info
# easy_install.py
# entrypoints-0.3-py3.6.egg-info
# entrypoints.py
# idna
# idna-2.8-py3.6.egg-info
# importlib_metadata
# importlib_metadata-0.23.dist-info
# ipykernel
# ipykernel-5.1.3.dist-info
# ipykernel_launcher.py
# ipython-7.9.0.dist-info
# ipython_genutils
# ...
